# %%
# !pip install onnxruntime
# Out:
# Collecting onnxruntime
#   Downloading onnxruntime-1.23.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.1 kB)
# Collecting coloredlogs (from onnxruntime)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/python/3.12.1/lib/python3.12/site-packages (from onnxruntime) (25.9.23)
# Requirement already satisfied: numpy>=1.21.6 in /home/codespace/.local/lib/python3.12/site-packages (from onnxruntime) (2.3.4)
# Requirement already satisfied: packaging in /home/codespace/.local/lib/python3.12/site-packages (from onnxruntime) (25.0)
# Requirement already satisfied: protobuf in /usr/local/python/3.12.1/lib/python3.12/site-packages (from onnxruntime) (3.20.3)
# Requirement already satisfied: sympy in /home/codespace/.local/lib/python3.12/site-packages (from onnxruntime) (1.14.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/codespace/.local/lib/python3.12/site-packages (from sympy->onnxruntime) (1.3.0)
# Downloading onnxruntime-1.23.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 29.9 MB/s  0:00:00 eta 0:00:01:01
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Installing collected packages: humanfriendly, coloredlogs, onnxruntime
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [onnxruntime]━━━━━━ 2/3 [onnxruntime]
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 onnxruntime-1.23.2

# %%
# !pip install keras-image-helper
# Out:
# Collecting keras-image-helper
#   Downloading keras_image_helper-0.0.2-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=2.3.2 in /home/codespace/.local/lib/python3.12/site-packages (from keras-image-helper) (2.3.4)
# Requirement already satisfied: pillow>=11.3.0 in /home/codespace/.local/lib/python3.12/site-packages (from keras-image-helper) (12.0.0)
# Downloading keras_image_helper-0.0.2-py3-none-any.whl (5.4 kB)
# Installing collected packages: keras-image-helper
# Successfully installed keras-image-helper-0.0.2

# %%
import onnxruntime as ort
from keras_image_helper import create_preprocessor

# %%
onnx_model_path = "clothing-model-new.onnx"
session = ort.InferenceSession(onnx_model_path, providers=["CPUExecutionProvider"])

# %%
inputs = session.get_inputs()
outputs = session.get_outputs()

# %%
input_name = inputs[0].name
output_name = outputs[0].name

# %%
preprocessor = create_preprocessor('xception', target_size=(299, 299))

url = 'http://bit.ly/mlbookcamp-pants'
X = preprocessor.from_url(url)

# %%
result = session.run([output_name], {input_name: X})
result
# Out:
# [array([[-2.3684335, -4.414736 , -2.309057 , -1.7397481,  8.660111 ,
#          -3.1949883, -5.595435 ,  2.7487986, -2.9956512, -4.36343  ]],
#        dtype=float32)]

# %%
predictions = result[0][0].tolist()

# %%
classes = [
    'dress',
    'hat',
    'longsleeve',
    'outwear',
    'pants',
    'shirt',
    'shoes',
    'shorts',
    'skirt',
    't-shirt'
]

dict(zip(classes, predictions))
# Out:
# {'dress': -2.3684334754943848,
#  'hat': -4.414735794067383,
#  'longsleeve': -2.3090569972991943,
#  'outwear': -1.7397481203079224,
#  'pants': 8.660111427307129,
#  'shirt': -3.194988250732422,
#  'shoes': -5.59543514251709,
#  'shorts': 2.7487986087799072,
#  'skirt': -2.9956512451171875,
#  't-shirt': -4.363430023193359}
